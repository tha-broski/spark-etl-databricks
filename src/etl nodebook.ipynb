# %%
from config import paths

print(paths.raw_file_path("products.csv"))
print(paths.table_name(paths.BRONZE_SCHEMA, "products"))
print(paths.table_name(paths.CONTROL_SCHEMA, "processed_files"))

# %%
import os

print(os.path.exists(paths.raw_file_path("products.csv")))
print(os.path.exists(paths.raw_file_path("customers.csv")))
print(os.path.exists(paths.raw_file_path("orders.csv")))
print(os.path.exists(paths.raw_file_path("order_items.csv")))

# %%
spark.sql("DROP TABLE IF EXISTS workspace.bronze.products")

# %%
from config import paths
df = spark.sql(f"SHOW SCHEMAS IN {paths.CATALOG}")
df.printSchema()
df.show()

# %%
# %sh
databricks --version

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.test")
